# %% [markdown]
# ## Visualizing the data of the immigrants to Canada using different visualizing libraries in Python

# %% [markdown]
# ### The dataset contains annual data on the flows of international immigrants as recorded by the countries of destination. The data presents both inflows and outflows according to the place of birth, citizenship or place of previous / next residence both for foreigners and nationals. The current version presents data pertaining to 45 countries

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# #### Importing the dataset

# %%
df_canada = pd.read_excel('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx',
                        sheet_name='Canada by Citizenship',
                        skiprows=range(20),
                        skipfooter=2
                       )

# %% [markdown]
# ### Dataset
# - Type: Type of immigrant admission (e.g., Immigrants, Emigrants, Returnees).
# - Coverage: Immigration data coverage (e.g., Foreigners, Citizens).
# - OdName: Name of the country or area of immigration.
# - AREA: Area code (e.g., 935 for World).
# - AreaName: Area name (e.g., Africa, Asia, Europe).
# - REG: Region code.
# - RegName: Region name (e.g., Northern America, Southern Asia).
# - DEV: Development region code.
# - DevName: Development region name (e.g., Developed regions, Developing regions).
#
# 1980 to 2022: Columns representing the number of immigrants for each year from 1980 to 2022.
#
# Note: The columns from '1980' to '2022' represent the number of immigrants for each year, and the actual values in these columns may vary based on the dataset's update and the current year when you access it.

# %%
df_canada['Coverage'].value_counts()
# Out:
# Coverage
# Foreigners    194
# Citizens        1
# Name: count, dtype: int64

# %%
df_canada
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# ...

# %%
df_canada.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1816  1852  3153
# 191     Northern Africa  902  Developing regions     0  ...     0     0     1
# 192        Western Asia  902  Developing regions     1  ...   124   161   140
# 193      Eastern Africa  902  Developing regions    11  ...    56    91    77
# 194      Eastern Africa  902  Developing regions    72  ...  1450   615   454
#
#      2007  2008  2009  2010  2011  2012  2013
# 190  2574  1784  2171  1942  1723  1731  2112
# ...

# %% [markdown]
# ### Exploring Data

# %%
df_canada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
# ...

# %%
sum(df_canada.isna().sum())
# Out:
# 0

# %%
df_canada.columns.values
# Out:
# array(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013], dtype=object)

# %%
df_canada['Type'].value_counts()
# Out:
# Type
# Immigrants    195
# Name: count, dtype: int64

# %%
df_canada.drop(['Type','Coverage' ,'AREA', 'REG', 'DEV'], axis=1, inplace=True)

# %%
df_canada.head(2)
# Out:
#         OdName AreaName          RegName             DevName  1980  1981  \
# 0  Afghanistan     Asia    Southern Asia  Developing regions    16    39
# 1      Albania   Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  2009  2010  \
# 0    39    47    71   340  ...  2978  3436  3009  2652  2111  1746  1758
# 1     0     0     0     0  ...  1450  1223   856   702   560   716   561
#
#    2011  2012  2013
# 0  2203  2635  2004
# 1   539   620   603
#
# [2 rows x 38 columns]

# %% [markdown]
# #### Rename Columns

# %%
df_canada.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_canada.head(2)
# Out:
#        Country Continent           Region             DevName  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  2009  2010  \
# 0    39    47    71   340  ...  2978  3436  3009  2652  2111  1746  1758
# 1     0     0     0     0  ...  1450  1223   856   702   560   716   561
#
#    2011  2012  2013
# 0  2203  2635  2004
# 1   539   620   603
#
# [2 rows x 38 columns]

# %% [markdown]
# #### Sum up the Total Immigrants by country

# %%
# sum the total immigrants by country
df_canada['Total'] = df_canada.sum(axis=1, numeric_only=True)

# %%
df_canada.head(2)
# Out:
#        Country Continent           Region             DevName  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2005  2006  2007  2008  2009  2010  2011  \
# 0    39    47    71   340  ...  3436  3009  2652  2111  1746  1758  2203
# 1     0     0     0     0  ...  1223   856   702   560   716   561   539
#
#    2012  2013  Total
# 0  2635  2004  58639
# 1   620   603  15699
#
# [2 rows x 39 columns]

# %%
df_canada.set_index('Country', inplace=True)
df_canada.head(2)
# Out:
#             Continent           Region             DevName  1980  1981  1982  \
# Country
# Afghanistan      Asia    Southern Asia  Developing regions    16    39    39
# Albania        Europe  Southern Europe   Developed regions     1     0     0
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# Country                              ...
# Afghanistan    47    71   340   496  ...  3436  3009  2652  2111  1746  1758
# Albania         0     0     0     1  ...  1223   856   702   560   716   561
#
#              2011  2012  2013  Total
# Country
# Afghanistan  2203  2635  2004  58639
# Albania       539   620   603  15699
#
# [2 rows x 38 columns]

# %% [markdown]
# #### convert the column names into strings: '1980' to '2013

# %%
df_canada.columns = list(map(str, df_canada.columns))
df_canada.columns
# Out:
# Index(['Continent', 'Region', 'DevName', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', 'Total'],
#       dtype='object')

# %%
years = list(map(str, range(1980, 2014)))
years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
df_canada[(df_canada['Continent'] == 'Asia') & (df_canada['Region'] == 'Western Asia')]
# Out:
#                      Continent        Region             DevName  1980  1981  \
# Country
# Armenia                   Asia  Western Asia  Developing regions     0     0
# Azerbaijan                Asia  Western Asia  Developing regions     0     0
# Bahrain                   Asia  Western Asia  Developing regions     0     2
# Cyprus                    Asia  Western Asia  Developing regions   132   128
# Georgia                   Asia  Western Asia  Developing regions     0     0
# Iraq                      Asia  Western Asia  Developing regions   262   245
# Israel                    Asia  Western Asia  Developing regions  1403  1711
# Jordan                    Asia  Western Asia  Developing regions   177   160
# Kuwait                    Asia  Western Asia  Developing regions     1     0
# Lebanon                   Asia  Western Asia  Developing regions  1409  1119
# Oman                      Asia  Western Asia  Developing regions     0     0
# ...

# %% [markdown]
# ### Visualizing data

# %% [markdown]
# #### Top 10 countries by total immigrants

# %%
df_canada.loc[df_canada.index].sort_values(by='Total', ascending=False).head(10)
# Out:
#                                                            Continent  \
# Country
# India                                                           Asia
# China                                                           Asia
# United Kingdom of Great Britain and Northern Ir...            Europe
# Philippines                                                     Asia
# Pakistan                                                        Asia
# United States of America                            Northern America
# Iran (Islamic Republic of)                                      Asia
# Sri Lanka                                                       Asia
# Republic of Korea                                               Asia
# Poland                                                        Europe
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# ...

# %%
India_immigrants = df_canada.loc['India', years]
India_immigrants
# Out:
# 1980     8880
# 1981     8670
# 1982     8147
# 1983     7338
# 1984     5704
# 1985     4211
# 1986     7150
# 1987    10189
# 1988    11522
# 1989    10343
# 1990    12041
# 1991    13734
# 1992    13673
# 1993    21496
# 1994    18620
# 1995    18489
# 1996    23859
# 1997    22268
# 1998    17241
# 1999    18974
# 2000    28572
# 2001    31223
# 2002    31889
# 2003    27155
# 2004    28235
# 2005    36210
# 2006    33848
# 2007    28742
# 2008    28261
# 2009    29456
# 2010    34235
# 2011    27509
# 2012    30933
# 2013    33087
# Name: India, dtype: object

# %%
India_immigrants.index = India_immigrants.index.map(int)
India_immigrants.index
# Out:
# Index([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013],
#       dtype='int64')

# %%
plt.figure(figsize=(10,5))
plt.plot(India_immigrants)
plt.title('Immigration from India to Canada from 1980 to 2013')
plt.xlabel('Years')
plt.ylabel('Number of immigrants')
plt.show()

# %% [markdown]
# #### compare the number of immigrants between India, China, UK, Philippines and Pakistan from 1980 to 2013

# %%
df_top_5 = df_canada.loc[['China','India', 'United Kingdom of Great Britain and Northern Ireland', 'Philippines', 'Pakistan'], years]
df_top_5
# Out:
#                                                      1980   1981   1982  \
# Country
# China                                                5123   6682   3308
# India                                                8880   8670   8147
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Philippines                                          6051   5921   5249
# Pakistan                                              978    972   1201
#
#                                                      1983   1984  1985  1986  \
# Country
# China                                                1863   1527  1816  1960
# India                                                7338   5704  4211  7150
# United Kingdom of Great Britain and Northern Ir...  10015  10170  9564  9470
# Philippines                                          4562   3801  3150  4166
# Pakistan                                              900    668   514   691
#
# ...

# %%
df_CI = df_canada.loc[['China','India'], years]
df_CI.head()
# Out:
#          1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# Country                                                                 ...
# China    5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
# India    8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
#
#           2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# Country
# China    36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
# India    28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
#
# [2 rows x 34 columns]

# %%
fig = plt.figure() # create figure

ax0 = fig.add_subplot(1, 2, 1) # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(1, 2, 2) # add subplot 2 (1 row, 2 columns, second plot)

# Subplot 1: Box plot
df_CI.transpose().plot(kind='box', color='blue', vert=False, figsize=(15, 6), ax=ax0) # add to subplot 1
ax0.set_title('Box Plots of Immigrants from China and India (1980 - 2013)')
ax0.set_xlabel('Number of Immigrants')
ax0.set_ylabel('Countries')

# Subplot 2: Line plot
df_CI.transpose().plot(kind='line', figsize=(15, 6), ax=ax1) # add to subplot 2
ax1.set_title ('Line Plots of Immigrants from China and India (1980 - 2013)')
ax1.set_ylabel('Number of Immigrants')
ax1.set_xlabel('Years')

plt.show()

# %%
df_top_5 = df_top_5[years]
df_top_5
# Out:
#                                                      1980   1981   1982  \
# Country
# China                                                5123   6682   3308
# India                                                8880   8670   8147
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Philippines                                          6051   5921   5249
# Pakistan                                              978    972   1201
#
#                                                      1983   1984  1985  1986  \
# Country
# China                                                1863   1527  1816  1960
# India                                                7338   5704  4211  7150
# United Kingdom of Great Britain and Northern Ir...  10015  10170  9564  9470
# Philippines                                          4562   3801  3150  4166
# Pakistan                                              900    668   514   691
#
# ...

# %%
df_top_5.transpose().plot(kind = 'area', stacked = False , alpha = 0.35,figsize = (20,5))
plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')
plt.show()

# %%
ax = df_top_5.transpose().plot(kind='area', stacked = True ,alpha=0.35, figsize=(20, 10))
ax.set_title('Immigration Trend of Top 5 Countries')
ax.set_ylabel('Number of Immigrants')
ax.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %% [markdown]
# #### Stacked area plot of the 5 countries that contributed the least to immigration to Canada from 1980 to 2013

# %%
df_least_5 = df_canada.loc[df_canada.index].sort_values(by = 'Total', ascending = True, axis = 0).head(5)
df_least_5=df_least_5[years]
df_least_5=df_least_5.iloc[0:5,:]
df_least_5=df_least_5.transpose()
df_least_5.head()
df_least_5.plot(kind='area', stacked = False, alpha=0.45, figsize = (20,5))
# Out:
# <Axes: >

# %% [markdown]
# #### frequency distribution of the number (population) of new immigrants from the various countries to Canada in 2013

# %%
df_top15 = df_canada['2013'].sort_values(ascending = False).head(15)

# %%
df_top15.plot(kind = 'barh', figsize = (10,5) ,color = 'red')
plt.xlabel('Number of Immigrants')
plt.title('Top 15 Countries Contributing to the Immigration to Canada between 1980 - 2013')
# Out:
# Text(0.5, 1.0, 'Top 15 Countries Contributing to the Immigration to Canada between 1980 - 2013')

# %%
count, bin_edges = np.histogram(df_canada['2013'])
print(bin_edges)

df_canada['2013'].plot(kind = 'hist', figsize = (15,5), xticks = bin_edges)
plt.title('Histogram of Immigration from 195 Countries in 2013') 
plt.ylabel('Number of Countries') 
plt.xlabel('Number of Immigrants')
plt.show()
# Out:
# [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]

# %% [markdown]
# #### immigration distribution for Denmark, Norway, and Sweden for years 1980 - 2013?

# %%
df_canada.loc[['Denmark', 'Norway', 'Sweden','Finland'], years].transpose()
# Out:
# Country  Denmark  Norway  Sweden  Finland
# 1980         272     116     281      208
# 1981         293      77     308      205
# 1982         299     106     222      170
# 1983         106      51     176       70
# 1984          93      31     128       83
# 1985          73      54     158       69
# 1986          93      56     187       68
# 1987         109      80     198       92
# 1988         129      73     171       89
# 1989         129      76     182       78
# 1990         118      83     130       73
# 1991         111     103     167       63
# 1992         158      74     179       76
# 1993         186      92     203       98
# 1994          93      60     192       99
# 1995         111      65     176       76
# 1996          70      70     161       58
# 1997          83     104     151       82
# 1998          63      31     123       55
# 1999          81      36     170       63
# 2000          93      56     138       70
# ...

# %%
df_canada.loc[['Denmark', 'Norway', 'Sweden','Finland'], years].transpose().plot(kind = 'hist', figsize = (15,5), stacked = True ,bins=15,alpha=0.6)
plt.title('Histogram of Immigration from Denmark, Norway, and Sweden from 1980 - 2013')
plt.xlabel('Number of Immigrants')
plt.ylabel('Number of Years')
plt.show()

# %% [markdown]
# ### Analyzing the effect of Iceland's Financial Crisis:

# %% [markdown]
# #### compare the number of Icelandic immigrants to Canada from year 1980 to 2013

# %%
df_iceland = df_canada.loc[df_canada.index == 'Iceland', years]
df_iceland
# Out:
#          1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Country                                                              ...
# Iceland    17    33    10     9    13     6    11    11     7     3  ...
#
#          2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# Country
# Iceland    23    10     2    15    13    15    30    38    42    72
#
# [1 rows x 34 columns]

# %%
df_iceland.transpose().plot(kind = 'bar', figsize = (20,6), color = 'red')
plt.xlabel('Year') 
plt.ylabel('Number of immigrants') 
plt.title('Icelandic immigrants to Canada from 1980 to 2013') 

# Annotate arrow
plt.annotate('',                      # s: str. Will leave it blank for no text
             xy=(32, 70),             # place head of the arrow at point (year 2012 , pop 70)
             xytext=(28, 20),         # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',         # will use the coordinate system of the object being annotated 
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
            )

# Annotate Text
plt.annotate('2008 - 2011 Financial Crisis', # text to display
             xy=(28, 30),                    # start the text at at point (year 2008 , pop 30)
             rotation=60,                    # based on trial and error to match the arrow
             va='bottom',                    # want the text to be vertically 'bottom' aligned
             ha='left',                      # want the text to be horizontally 'left' aligned
            )

plt.show()

# %% [markdown]
# #### Immigration by Continent

# %%
df_continent = df_canada.groupby('Continent').sum()
df_continent
# Out:
#                                                                             Region  \
# Continent
# Africa                           Northern AfricaMiddle AfricaWestern AfricaSout...
# Asia                             Southern AsiaWestern AsiaWestern AsiaWestern A...
# Europe                           Southern EuropeSouthern EuropeWestern EuropeEa...
# Latin America and the Caribbean  CaribbeanSouth AmericaCaribbeanCaribbeanCentra...
# Northern America                                  Northern AmericaNorthern America
# Oceania                          PolynesiaAustralia and New ZealandMelanesiaMic...
#
#                                                                            DevName  \
# Continent
# Africa                           Developing regionsDeveloping regionsDeveloping...
# Asia                             Developing regionsDeveloping regionsDeveloping...
# Europe                           Developed regionsDeveloped regionsDeveloped re...
# ...

# %%
df_continent['Total'].plot(kind='pie',
                            figsize=(10, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=40,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Immigration to Canada by Continent [1980 - 2013]')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.

df_continent['Total'].plot(kind='pie',
                            figsize=(10, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.15,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('Immigration to Canada by Continent [1980 - 2013]', y=1.12) 

plt.axis('equal') 

# add legend
plt.legend(labels=df_continent.index, loc='upper left') 

plt.show()

# %% [markdown]
# #### Box plot to visualize the distribution of the top 15 countries (based on total immigration) grouped by the decades

# %%
df_top15 = df_canada.loc[df_canada.index].sort_values(by = 'Total', ascending = False)
df_top15 = df_top15[years].head(15)
df_top15
# Out:
#                                                      1980   1981   1982  \
# Country
# India                                                8880   8670   8147
# China                                                5123   6682   3308
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Philippines                                          6051   5921   5249
# Pakistan                                              978    972   1201
# United States of America                             9378  10030   9074
# Iran (Islamic Republic of)                           1172   1429   1822
# Sri Lanka                                             185    371    290
# Republic of Korea                                    1011   1456   1572
# Poland                                                863   2930   5881
# Lebanon                                              1409   1119   1159
# France                                               1729   2027   2219
# ...

# %%
df_80s = df_top15.iloc[:, 0:10].sum(axis = 1)
df_90s = df_top15.iloc[:, 10:20].sum(axis = 1)
df_00s = df_top15.iloc[:, 20:].sum(axis = 1)

new_df = pd.DataFrame({'1980s': df_80s, '1990s': df_90s, '2000s':df_00s})
new_df
# Out:
#                                                      1980s   1990s   2000s
# Country
# India                                                82154  180395  429355
# China                                                32003  161528  466431
# United Kingdom of Great Britain and Northern Ir...  179171  261966  110363
# Philippines                                          60764  138482  312145
# Pakistan                                             10591   65302  165707
# United States of America                             76824   56915  107383
# Iran (Islamic Republic of)                           21477   54871   99575
# Sri Lanka                                            14796   70421   63141
# Republic of Korea                                    16259   38189   88133
# Poland                                               57602   64864   16775
# Lebanon                                              24918   49245   41196
# ...

# %%
new_df.describe()
# Out:
#                1980s          1990s          2000s
# count      15.000000      15.000000      15.000000
# mean    44418.333333   85594.666667  138333.266667
# std     44190.676455   68237.560246  145288.871956
# min      7613.000000   30028.000000   16775.000000
# 25%     16698.000000   39259.000000   46754.500000
# 50%     30638.000000   56915.000000   88133.000000
# 75%     59183.000000  104451.500000  138035.000000
# max    179171.000000  261966.000000  466431.000000

# %%
new_df.plot(kind='box',figsize=(10, 6))
# Out:
# <Axes: >

# %%
df_tot = pd.DataFrame(df_canada[years].sum(axis=0))
df_tot.index = map(int, df_tot.index)
df_tot.reset_index(inplace = True)
df_tot.columns = ['year', 'total']
df_tot.head()
# Out:
#    year   total
# 0  1980   99137
# 1  1981  110563
# 2  1982  104271
# 3  1983   75550
# 4  1984   73417

# %%
x = df_tot['year']       
y = df_tot['total']     
fit = np.polyfit(x, y, deg=1)

df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')
# plot line of best fit
plt.plot(x, fit[0] * x + fit[1], color='red') # recall that x is the Years
plt.annotate('y={0:.0f} x + {1:.0f}'.format(fit[0], fit[1]), xy=(2000, 140000))

# print out the line of best fit
'No. Immigrants = {0:.0f} * Year + {1:.0f}'.format(fit[0], fit[1]) 
plt.show()

# %% [markdown]
# #### Scatter plot of the total immigration from Denmark, Norway, and Sweden to Canada from 1980 to 2013

# %%
df_canada.loc[['Denmark', 'Norway', 'Sweden'], years].transpose()
# Out:
# Country  Denmark  Norway  Sweden
# 1980         272     116     281
# 1981         293      77     308
# 1982         299     106     222
# 1983         106      51     176
# 1984          93      31     128
# 1985          73      54     158
# 1986          93      56     187
# 1987         109      80     198
# 1988         129      73     171
# 1989         129      76     182
# 1990         118      83     130
# 1991         111     103     167
# 1992         158      74     179
# 1993         186      92     203
# 1994          93      60     192
# 1995         111      65     176
# 1996          70      70     161
# 1997          83     104     151
# 1998          63      31     123
# 1999          81      36     170
# 2000          93      56     138
# 2001          81      78     184
# 2002          70      74     149
# 2003          89      77     161
# 2004          89      73     129
# 2005          62      57     205
# 2006         101      53     139
# ...

# %%
df_total = pd.DataFrame(df_canada.loc[['Denmark', 'Norway', 'Sweden'], years].transpose().sum(axis=1)).reset_index()
df_total.columns = ['year', 'total']
df_total['year'] = df_total['year'].map(int)
df_total.head()
# Out:
#    year  total
# 0  1980    669
# 1  1981    678
# 2  1982    627
# 3  1983    333
# 4  1984    252

# %%
df_total.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')
plt.title('Immigration from Denmark, Norway, and Sweden to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')
plt.show()

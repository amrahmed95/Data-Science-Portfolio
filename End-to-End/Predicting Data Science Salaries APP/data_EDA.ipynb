# %% [markdown]
# # Exploratory Data Analysis (EDA) for Data Science Salaries - Glassdoor Dataset

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# ## Importing cleaned Dataset

# %%
df = pd.read_csv('Data_Science_Salaries_cleaned.csv')
df.head()
# Out:
#                    Job_Title Salary_Estimate  \
# 0             Data Scientist           53-91
# 1  Healthcare Data Scientist          63-112
# 2             Data Scientist           80-90
# 3             Data Scientist           56-97
# 4             Data Scientist          86-143
#
#                                      Job_Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company_Name         Location     Headquarter  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4   Clearwater, FL  Clearwater, FL
# 3                                   PNNL     Richland, WA    Richland, WA
# 4                     Affinity Solutions     New York, NY    New York, NY
#
#                      Size  Founded   Type_of_ownership  ... Job_state  \
# 0   501 to 1000 employees     1973   Company - Private  ...        NM
# 1        10000+ employees     1984  Other Organization  ...        MD
# 2   501 to 1000 employees     2010   Company - Private  ...        FL
# 3  1001 to 5000 employees     1965          Government  ...        WA
# 4     51 to 200 employees     1998   Company - Private  ...        NY
#
#   same_state age_of_company Python R-studio spark  Excel  AWS  \
# 0          0             50      1        0     0      1    0
# 1          0             39      1        0     0      0    0
# 2          1             13      1        0     1      1    0
# 3          1             58      1        0     0      0    0
# 4          1             25      1        0     0      1    0
#
#    Seniority_Level  Job_Title_Simplified
# 0               na        data scientist
# 1               na        data scientist
# 2               na        data scientist
# 3               na        data scientist
# 4               na        data scientist
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Job_Title', 'Salary_Estimate', 'Job_Description', 'Rating',
#        'Company_Name', 'Location', 'Headquarter', 'Size', 'Founded',
#        'Type_of_ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'seniority', 'Job_Title_simplified', 'PerHour',
#        'employer_Provided_Salary', 'min_salary', 'max_salary',
#        'average_salary', 'Job_state', 'same_state', 'age_of_company', 'Python',
#        'R-studio', 'spark', 'Excel', 'AWS', 'Seniority_Level',
#        'Job_Title_Simplified'],
#       dtype='object')

# %%
df['Job_Title_Simplified'].value_counts()
# Out:
# Job_Title_Simplified
# data scientist      279
# na                  184
# data engineer       119
# analyst             102
# manager              22
# machine learning     22
# director             14
# Name: count, dtype: int64

# %%
df['Seniority_Level'].value_counts()
# Out:
# Seniority_Level
# na           519
# senior       173
# principal     25
# lead          22
# junior         3
# Name: count, dtype: int64

# %% [markdown]
# #### FIx state 'Los Angeles'

# %%
df['Job_state'].value_counts()
# Out:
# Job_state
# CA             151
# MA             103
# NY              72
# VA              41
# IL              40
# MD              35
# PA              33
# TX              28
# WA              21
# NC              21
# NJ              17
# FL              16
# OH              14
# TN              13
# DC              11
# CO              11
# WI              10
# IN              10
# UT              10
# AZ               9
# MO               9
# AL               8
# GA               6
# KY               6
# DE               6
# MI               6
# CT               5
# IA               5
# LA               4
# OR               4
# NE               4
# NM               3
# KS               3
# ID               2
# MN               2
# Los Angeles      1
# RI               1
# SC               1
# Name: count, dtype: int64

# %%
df[df['Job_state'] == 'Los Angeles']
# Out:
#           Job_Title Salary_Estimate  \
# 126  Data Scientist          82-133
#
#                                        Job_Description  Rating  \
# 126  For more than 50 years, Accuride International...     3.6
#
#                Company_Name                           Location  \
# 126  Accuride International  Santa Fe Springs, Los Angeles, CA
#
#               Headquarter                    Size  Founded  Type_of_ownership  \
# 126  Santa Fe Springs, CA  1001 to 5000 employees     1966  Company - Private
#
#      ...    Job_state same_state age_of_company Python R-studio spark  Excel  \
# 126  ...  Los Angeles          0             57      0        0     0      1
#
#      AWS  Seniority_Level  Job_Title_Simplified
# 126    0               na        data scientist
#
# [1 rows x 31 columns]

# %%
df['Job_state'].loc[126].strip().lower()
# Out:
# 'los angeles'

# %%
df['Job_state'] = df['Job_state'].apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')

# %%
df['Job_state'].value_counts()
# Out:
# Job_state
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: count, dtype: int64

# %% [markdown]
# #### Job Description Length

# %%
df['Job_Description_Length'] = df['Job_Description'].apply(len)

# %%
df['Job_Description_Length']
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: Job_Description_Length, Length: 742, dtype: int64

# %% [markdown]
# #### Competitor Count

# %%
df['Competitors'].value_counts()
# Out:
# Competitors
# -1                                                                                              460
# Novartis, Baxter, Pfizer                                                                         14
# Oak Ridge National Laboratory, National Renewable Energy Lab, Los Alamos National Laboratory     12
# Travelers, Allstate, State Farm                                                                  10
# Roche, GlaxoSmithKline, Novartis                                                                  9
#                                                                                                ...
# BrowserStack, Selenium Master, Perfecto Mobile                                                    1
# Boeing, Northrop Grumman, Raytheon                                                                1
# Unilever, Procter & Gamble, Henkel                                                                1
# TASC, Vencore, Booz Allen Hamilton                                                                1
# Belly, SpotOn                                                                                     1
# Name: count, Length: 128, dtype: int64

# %%
df['Number_of_Competitors'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != -1 else 0)
df['Number_of_Competitors'].value_counts()
# Out:
# Number_of_Competitors
# 1    472
# 3    228
# 2     41
# 4      1
# Name: count, dtype: int64

# %% [markdown]
# #### hourly wage (min & max salary) to an annual wage
#
# - 8hrs/day * 5 days/week * 50 working weeks = 2000

# %%
# convert min salary associated with perhour ==1 to an annual salary
df['min_salary'][df['PerHour'] == 1] = df['min_salary'][df['PerHour'] == 1]*2
df['max_salary'][df['PerHour'] == 1] = df['max_salary'][df['PerHour'] == 1]*2
df['average_salary'][df['PerHour'] == 1] = df['average_salary'][df['PerHour'] == 1]*2
# Out:
# C:\Users\Amr Ahmed\AppData\Local\Temp\ipykernel_10064\4161430544.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_salary'][df['PerHour'] == 1] = df['min_salary'][df['PerHour'] == 1]*2
# C:\Users\Amr Ahmed\AppData\Local\Temp\ipykernel_10064\4161430544.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_salary'][df['PerHour'] == 1] = df['max_salary'][df['PerHour'] == 1]*2
# C:\Users\Amr Ahmed\AppData\Local\Temp\ipykernel_10064\4161430544.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['average_salary'][df['PerHour'] == 1] = df['average_salary'][df['PerHour'] == 1]*2

# %%
df[['PerHour','min_salary', 'max_salary', 'average_salary']].loc[df['PerHour'] == 1]
# Out:
#      PerHour  min_salary  max_salary  average_salary
# 165        1          34          48            41.0
# 177        1          42          68            55.0
# 197        1          36          50            43.0
# 202        1          42          68            55.0
# 210        1          30          50            40.0
# 246        1          34          48            41.0
# 271        1          42          68            55.0
# 337        1          36          50            43.0
# 345        1          48          78            63.0
# 357        1          42          68            55.0
# 363        1          50          56            53.0
# 408        1          42          58            50.0
# 409        1          20          34            27.0
# 492        1          36          50            43.0
# 509        1          48          78            63.0
# 533        1          42          68            55.0
# 542        1          50          56            53.0
# 617        1          42          58            50.0
# 618        1          20          34            27.0
# 645        1          54          94            74.0
# 666        1          36          50            43.0
# 682        1          48          78            63.0
# 711        1          42          68            55.0
# 724        1          50          56            53.0

# %% [markdown]
# ---------------------

# %%
df.describe()
# Out:
#            Rating      Founded     PerHour  employer_Provided_Salary  \
# count  742.000000   742.000000  742.000000                742.000000
# mean     3.618868  1837.154987    0.032345                  0.022911
# std      0.801210   497.183763    0.177034                  0.149721
# min     -1.000000    -1.000000    0.000000                  0.000000
# 25%      3.300000  1939.000000    0.000000                  0.000000
# 50%      3.700000  1988.000000    0.000000                  0.000000
# 75%      4.000000  2007.000000    0.000000                  0.000000
# max      5.000000  2019.000000    1.000000                  1.000000
#
#        min_salary  max_salary  average_salary  same_state  age_of_company  \
# count  742.000000  742.000000      742.000000  742.000000      742.000000
# mean    74.719677  128.149596      101.434636    0.557951       49.389488
# std     30.980593   45.220324       37.546122    0.496965       53.962906
# min     15.000000   16.000000       15.500000    0.000000       -1.000000
# 25%     52.000000   96.000000       73.500000    0.000000       14.000000
# 50%     69.500000  124.000000       97.500000    1.000000       27.000000
# 75%     91.000000  155.000000      122.500000    1.000000       62.000000
# max    202.000000  306.000000      254.000000    1.000000      279.000000
#
#            Python    R-studio       spark       Excel         AWS  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000
# mean     0.528302    0.002695    0.225067    0.522911    0.237197
# std      0.499535    0.051882    0.417908    0.499812    0.425651
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    1.000000    0.000000
# 75%      1.000000    0.000000    0.000000    1.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Job_Description_Length  Number_of_Competitors
# count              742.000000             742.000000
# mean              3869.545822               1.673854
# std               1521.495868               0.918451
# min                407.000000               1.000000
# 25%               2801.000000               1.000000
# 50%               3731.000000               1.000000
# 75%               4740.000000               3.000000
# max              10051.000000               4.000000

# %%
df.describe(include = 'object').T
# Out:
#                      count unique  \
# Job_Title              742    264
# Salary_Estimate        742    416
# Job_Description        742    463
# Company_Name           742    343
# Location               742    200
# Headquarter            742    198
# Size                   742      9
# Type_of_ownership      742     11
# Industry               742     60
# Sector                 742     25
# Revenue                742     14
# Competitors            742    128
# seniority              742      5
# Job_Title_simplified   742      7
# Job_state              742     37
# Seniority_Level        742      5
# Job_Title_Simplified   742      7
#
#                                                                     top freq
# Job_Title                                                Data Scientist  131
# Salary_Estimate                                                  49-113    6
# Job_Description       Description\nMedical Laboratory Scientist - Te...    4
# Company_Name                                                 MassMutual   14
# Location                                                   New York, NY   55
# Headquarter                                                New York, NY   52
# Size                                             1001 to 5000 employees  150
# Type_of_ownership                                     Company - Private  410
# Industry                                      Biotech & Pharmaceuticals  112
# Sector                                           Information Technology  180
# Revenue                                        Unknown / Non-Applicable  203
# Competitors                                                          -1  460
# seniority                                                            na  519
# Job_Title_simplified                                     data scientist  279
# Job_state                                                            CA  152
# Seniority_Level                                                      na  519
# Job_Title_Simplified                                     data scientist  279

# %%
df.head(5)
# Out:
#                    Job_Title Salary_Estimate  \
# 0             Data Scientist           53-91
# 1  Healthcare Data Scientist          63-112
# 2             Data Scientist           80-90
# 3             Data Scientist           56-97
# 4             Data Scientist          86-143
#
#                                      Job_Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company_Name         Location     Headquarter  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# 2                                KnowBe4   Clearwater, FL  Clearwater, FL
# 3                                   PNNL     Richland, WA    Richland, WA
# 4                     Affinity Solutions     New York, NY    New York, NY
#
#                      Size  Founded   Type_of_ownership  ... age_of_company  \
# 0   501 to 1000 employees     1973   Company - Private  ...             50
# 1        10000+ employees     1984  Other Organization  ...             39
# 2   501 to 1000 employees     2010   Company - Private  ...             13
# 3  1001 to 5000 employees     1965          Government  ...             58
# 4     51 to 200 employees     1998   Company - Private  ...             25
#
#   Python R-studio spark Excel AWS  Seniority_Level  Job_Title_Simplified  \
# 0      1        0     0     1   0               na        data scientist
# 1      1        0     0     0   0               na        data scientist
# 2      1        0     1     1   0               na        data scientist
# 3      1        0     0     0   0               na        data scientist
# 4      1        0     0     1   0               na        data scientist
#
#    Job_Description_Length  Number_of_Competitors
# 0                    2536                      1
# 1                    4783                      1
# 2                    3461                      1
# 3                    3883                      3
# 4                    2728                      3
#
# [5 rows x 33 columns]

# %%
numerical_columns = ['Rating', 'min_salary', 'max_salary', 'average_salary', 'age_of_company' ,'Job_Description_Length', 'Number_of_Competitors']
categorical_columns = ['Job_Title_Simplified', 'Location','Headquarter', 'Size', 'Type_of_ownership', 'Industry', 'Sector', 'Revenue', 'Job_state', 'spark', 'R-studio', 'Python', 'Excel', 'AWS', 'Seniority_Level']

# %%
for column in numerical_columns:
    df[column] = df[column].astype('float')
    
for column in categorical_columns:
    df[column] = df[column].astype('category')

# %% [markdown]
# ## EDA - Numerical Variables

# %% [markdown]
# #### Histograms

# %%
df[numerical_columns].hist(bins = 20, figsize = (20,15), layout = (3,4), edgecolor = 'black')
# Out:
# array([[<Axes: title={'center': 'Rating'}>,
#         <Axes: title={'center': 'min_salary'}>,
#         <Axes: title={'center': 'max_salary'}>,
#         <Axes: title={'center': 'average_salary'}>],
#        [<Axes: title={'center': 'age_of_company'}>,
#         <Axes: title={'center': 'Job_Description_Length'}>,
#         <Axes: title={'center': 'Number_of_Competitors'}>, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# #### Boxplot

# %%
df.boxplot(column = ['Rating','age_of_company', 'average_salary'])
# Out:
# <Axes: >

# %%
df.boxplot(column = ['Rating'])
# Out:
# <Axes: >

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(df[numerical_columns])

# %% [markdown]
# #### Correlation

# %%
df[numerical_columns].corr()
# Out:
#                           Rating  min_salary  max_salary  average_salary  \
# Rating                  1.000000   -0.009573    0.027344        0.012517
# min_salary             -0.009573    1.000000    0.940136        0.978714
# max_salary              0.027344    0.940136    1.000000        0.990066
# average_salary          0.012517    0.978714    0.990066        1.000000
# age_of_company          0.026164    0.002640    0.034421        0.021817
# Job_Description_Length -0.012281    0.060420    0.075634        0.070474
# Number_of_Competitors   0.021395    0.069964    0.081629        0.078022
#
#                         age_of_company  Job_Description_Length  \
# Rating                        0.026164               -0.012281
# min_salary                    0.002640                0.060420
# max_salary                    0.034421                0.075634
# average_salary                0.021817                0.070474
# age_of_company                1.000000                0.164730
# Job_Description_Length        0.164730                1.000000
# Number_of_Competitors         0.139800                0.109321
#
#                         Number_of_Competitors
# Rating                               0.021395
# min_salary                           0.069964
# max_salary                           0.081629
# average_salary                       0.078022
# age_of_company                       0.139800
# Job_Description_Length               0.109321
# Number_of_Competitors                1.000000

# %%
sns.heatmap(df[numerical_columns].corr(), annot = True, linewidths = 0.5, linecolor = 'black', fmt = '.2f', cmap = 'YlGnBu', cbar = True, square = True, cbar_kws= {'shrink': .5})
# Out:
# <Axes: >

# %% [markdown]
# ## EDA - Categorical Variables

# %%
categorical_columns
# Out:
# ['Job_Title_Simplified',
#  'Location',
#  'Headquarter',
#  'Size',
#  'Type_of_ownership',
#  'Industry',
#  'Sector',
#  'Revenue',
#  'Job_state',
#  'spark',
#  'R-studio',
#  'Python',
#  'Excel',
#  'AWS',
#  'Seniority_Level']

# %%
df['Job_Title_Simplified'].value_counts().plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'Job Title', ylabel = 'Count', grid = True)
# Out:
# <Axes: xlabel='Job Title', ylabel='Count'>

# %%
df['Seniority_Level'].value_counts().plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'Seniority', ylabel = 'Count', grid = True)
# Out:
# <Axes: xlabel='Seniority', ylabel='Count'>

# %%
df['Location'].value_counts().head(30).plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (20,5), xlabel = 'Location', ylabel = 'Count', grid = True)

# Color the top 5 with red
for patch in plt.gca().patches[:5]:
    patch.set_facecolor('red')

# %%
df['Headquarter'].value_counts().head(30).plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (20,5), xlabel = 'Headquarter', ylabel = 'Count', grid = True)

# Color the top 5 with red
for patch in plt.gca().patches[:5]:
    patch.set_facecolor('red')

# %%
df['Size'].value_counts().head(30).plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (20,5), xlabel = 'Size', ylabel = 'Count', grid = True)
# Out:
# <Axes: xlabel='Size', ylabel='Count'>

# %%
df['Type_of_ownership'].value_counts().plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'Type Of Ownership', ylabel = 'Count', grid = True)
# Out:
# <Axes: xlabel='Type Of Ownership', ylabel='Count'>

# %%
df['Industry'].value_counts().head(20).plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'Industry', ylabel = 'Count', grid = True)

# Color the top 10 with red
for patch in plt.gca().patches[:10]:
    patch.set_facecolor('red')

# %%
df['Sector'].value_counts().head(20).plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'Sector', ylabel = 'Count', grid = True)


# Color the top 10 with red
for patch in plt.gca().patches[:10]:
    patch.set_facecolor('red')

# %%
df['Revenue'].value_counts().head(20).plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'Revenue', ylabel = 'Count', grid = True)


# Color the top 5 with red
for patch in plt.gca().patches[1:6]:
    patch.set_facecolor('red')

# %%
df['Job_state'].value_counts().head(20).plot.bar( color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'Job State', ylabel = 'Count', grid = True)


# Color the top 5 with red
for patch in plt.gca().patches[:5]:
    patch.set_facecolor('red')

# %%
df['AWS'].value_counts().plot.bar(color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'AWS', ylabel = 'Count', grid = True)
# Out:
# <Axes: xlabel='AWS', ylabel='Count'>

# %%
df['Python'].value_counts().plot.bar(color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'python', ylabel = 'Count', grid = True)
# Out:
# <Axes: xlabel='python', ylabel='Count'>

# %%
df['R-studio'].value_counts().plot.bar(color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'R-studio', ylabel = 'Count', grid = True)
# Out:
# <Axes: xlabel='R-studio', ylabel='Count'>

# %%
df['spark'].value_counts().plot.bar(color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'spark', ylabel = 'Count', grid = True)
# Out:
# <Axes: xlabel='spark', ylabel='Count'>

# %%
df['Excel'].value_counts().plot.bar(color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'Excel', ylabel = 'Count', grid = True)
# Out:
# <Axes: xlabel='Excel', ylabel='Count'>

# %% [markdown]
# #### Numerical Vs. Categorical Variables

# %%
pd.pivot_table(df, index = 'Job_Title_Simplified', values = 'average_salary')
# Out:
#                       average_salary
# Job_Title_Simplified
# analyst                    66.122549
# data engineer             105.403361
# data scientist            117.564516
# director                  168.607143
# machine learning          126.431818
# manager                    84.022727
# na                         87.967391

# %%
pd.pivot_table(df, index = 'Job_Title_Simplified', values = 'average_salary').plot.bar(color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (10,5), xlabel = 'Job Title', ylabel = 'Count', grid = True, rot = 0)
# Out:
# <Axes: xlabel='Job Title', ylabel='Count'>

# %%
pd.pivot_table(df, index = ['Job_Title_Simplified', 'Seniority_Level'], values = 'average_salary')
# Out:
#                                       average_salary
# Job_Title_Simplified Seniority_Level
# analyst              junior                53.250000
#                      lead                  64.666667
#                      na                    61.308219
#                      senior                82.020833
# data engineer        lead                 161.142857
#                      na                    96.701220
#                      principal            162.500000
#                      senior               114.586207
# data scientist       junior               106.500000
#                      lead                 158.300000
#                      na                   107.043011
#                      principal            175.300000
#                      senior               131.222222
# director             na                   168.607143
# machine learning     na                   119.133333
#                      principal            232.500000
#                      senior               127.000000
# manager              na                    84.022727
# na                   lead                 110.000000
#                      na                    78.500000
#                      principal            105.192308
#                      senior               110.214286

# %%
pd.pivot_table(df, index = ['Job_state','Job_Title_Simplified'], values = 'average_salary', aggfunc = 'count', margins = True, margins_name = 'All').sort_values('average_salary', ascending = False).head(30)
# Out:
#                                 average_salary
# Job_state Job_Title_Simplified
# All                                        742
# CA        data scientist                    68
# MA        na                                46
# NY        data scientist                    40
# MA        data scientist                    30
# CA        na                                27
#           data engineer                     25
# VA        data scientist                    18
# CA        analyst                           18
# WA        data scientist                    17
# MD        na                                16
# IL        data scientist                    15
# NY        analyst                           14
# TX        data scientist                    13
# MD        data scientist                    13
# NC        na                                12
# NY        na                                12
# MA        data engineer                     12
# VA        data engineer                     10
# TN        data engineer                     10
# CA        manager                            9
# PA        analyst                            8
# IL        data engineer                      8
# PA        na                                 8
# TX        data engineer                      8
# FL        data scientist                     7
# TX        na                                 7
# PA        machine learning                   7
# OH        data scientist                     7
# IL        director                           6

# %%
pd.pivot_table(df[df.Job_Title_Simplified == 'data scientist'], index = ['Job_state'], values = 'average_salary').sort_values('average_salary', ascending = False)
# Out:
#            average_salary
# Job_state
# DC             149.000000
# CA             142.522059
# UT             140.500000
# MO             127.666667
# IL             117.233333
# NC             117.000000
# NY             115.250000
# MA             113.750000
# WI             113.500000
# PA             113.333333
# MD             109.115385
# CO             108.666667
# VA             108.416667
# NJ             106.875000
# MI             106.625000
# OH             105.285714
# TX             100.730769
# WA              99.764706
# OR              98.500000
# FL              97.357143
# TN              96.000000
# IN              84.500000
# KY              84.000000
# CT              84.000000
# GA              81.333333
# NM              74.333333
# AZ              69.500000

# %%
pd.pivot_table(df[df.Job_Title_Simplified == 'data scientist'], index = ['Job_state'], values = 'average_salary').sort_values('average_salary', ascending = False).head(20).plot.bar(color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (20,5), xlabel = 'Job state - avg salary - Data Scientist', ylabel = 'Count', grid = True, rot = 0)

# Color the top 5 with red
for patch in plt.gca().patches[:5]:
    patch.set_facecolor('red')

# %%
pd.pivot_table(df, index = ['Job_state'], values = 'average_salary').sort_values('average_salary', ascending = False).head(20).plot.bar(color = 'green', edgecolor = 'black', linewidth = 2, width = 0.5, figsize = (20,5), xlabel = 'Job state - avg salary - all jobs titles', ylabel = 'Count', grid = True, rot = 0)

# Color the top 5 with red
for patch in plt.gca().patches[:5]:
    patch.set_facecolor('red')

# %%
pd.pivot_table(df, index = ['Job_state','Job_Title_Simplified'], values = 'average_salary').sort_values('average_salary', ascending = False).head(20)
# Out:
#                                 average_salary
# Job_state Job_Title_Simplified
# IL        director                  221.750000
# CA        machine learning          177.300000
# NJ        director                  161.500000
# DC        data scientist            149.000000
# CA        data scientist            142.522059
# UT        data scientist            140.500000
# IL        machine learning          133.000000
# CA        data engineer             129.540000
# MO        data scientist            127.666667
# NY        machine learning          125.000000
# AZ        na                        124.500000
# PA        machine learning          120.500000
# MA        director                  117.833333
# IL        data scientist            117.233333
# NC        data scientist            117.000000
# NY        data scientist            115.250000
# IN        data engineer             114.500000
# MA        data scientist            113.750000
# WI        data scientist            113.500000
# PA        data scientist            113.333333

# %%
categorical_columns
# Out:
# ['Job_Title_Simplified',
#  'Location',
#  'Headquarter',
#  'Size',
#  'Type_of_ownership',
#  'Industry',
#  'Sector',
#  'Revenue',
#  'Job_state',
#  'spark',
#  'R-studio',
#  'Python',
#  'Excel',
#  'AWS',
#  'Seniority_Level']

# %%
for i in categorical_columns:
    print(pd.pivot_table(df, index = i, values = 'average_salary', sort=True).sort_values('average_salary', ascending = False).head(5))
# Out:
#                       average_salary
# Job_Title_Simplified
# director                  168.607143
# machine learning          126.431818
# data scientist            117.564516
# data engineer             105.403361
# na                         87.967391
#                    average_salary
# Location
# Bellevue, WA             184.5000
# Lake Forest, IL          179.5000
# Mountain View, CA        177.1875
# Novato, CA               168.0000
# Burbank, CA              164.0000
#                    average_salary
# Headquarter
# Fremont, CA            225.000000
# Lake Forest, IL        179.500000
# Burbank, CA            164.000000
# Mill Valley, CA        162.000000
# Mountain View, CA      158.818182
#                      average_salary
# Size
# Unknown                  128.111111
# -1                       117.500000
# 10000+ employees         112.769231
# 51 to 200 employees      111.744681
# 1 to 50 employees        104.870968
#                                 average_salary
# Type_of_ownership
# -1                                  117.500000
# Company - Public                    111.033679
# Subsidiary or Business Segment      110.573529
# College / University                107.615385
# Company - Private                   102.060976
#                                           average_salary
# Industry
# Other Retail Stores                              163.500
# Motion Picture Production & Distribution         146.000
# Financial Analytics & Research                   145.125
# Health, Beauty, & Fitness                        139.500
# Telecommunications Services                      131.500
#                            average_salary
# Sector
# Media                          116.666667
# -1                             114.650000
# Accounting & Legal             113.500000
# Information Technology         113.191667
# Biotech & Pharmaceuticals      112.098214
#                             average_salary
# Revenue
# $5 to $10 million (USD)         126.111111
# $1 to $5 million (USD)          119.312500
# -1                              117.500000
# $10+ billion (USD)              115.568548
# Less than $1 million (USD)      108.625000
#            average_salary
# Job_state
# CA             123.513158
# IL             116.662500
# DC             110.181818
# MA             107.412621
# NJ             104.558824
#        average_salary
# spark
# 1          113.347305
# 0           97.974783
#           average_salary
# R-studio
# 0             101.517568
# 1              70.750000
#         average_salary
# Python
# 1           112.653061
# 0            88.870000
#        average_salary
# Excel
# 0          104.242938
# 1           98.872423
#      average_salary
# AWS
# 1        113.048295
# 0         97.823322
#                  average_salary
# Seniority_Level
# lead                 142.045455
# principal            140.620000
# senior               116.361272
# na                    93.026012
# junior                71.000000

# %%
# Revenue of company vs python

pd.pivot_table(df, index = 'Revenue', columns = 'Python', values = 'average_salary', aggfunc = 'count').sort_values(1, ascending = False)
# Out:
# Python                             0    1
# Revenue
# Unknown / Non-Applicable          93  110
# $10+ billion (USD)                66   58
# $1 to $2 billion (USD)            16   44
# $100 to $500 million (USD)        47   44
# $500 million to $1 billion (USD)  29   28
# $50 to $100 million (USD)         21   25
# $2 to $5 billion (USD)            17   22
# $10 to $25 million (USD)          16   16
# $25 to $50 million (USD)          24   16
# $5 to $10 billion (USD)            9   10
# $5 to $10 million (USD)            9    9
# $1 to $5 million (USD)             1    7
# Less than $1 million (USD)         1    3
# -1                                 1    0

# %%
# implement code to generate wordcloud for Job_description
import wordcloud
from wordcloud import WordCloud, STOPWORDS

text = " ".join(i for i in df.Job_Description)
#stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ----------------------

# %% [markdown]
# ---------------
